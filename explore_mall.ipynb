# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import acquire
import wrangle
import explore
import sklearn.preprocessing
import prepare

# %%
## acquire mall data

df = acquire.get_mall_data()

# %%
# lets check the shape of the data


df.shape
# Out:
# (200, 5)

# %%
# lets take a look at the data


df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
# get our train, test, validate split using the prep data function



train, test, validate = prepare.prep_mall_data(df)

# %%
# lets check the shape of the splitted data



train.shape, validate.shape, test.shape
# Out:
# ((144, 6), (26, 6), (30, 6))

# %%
test.head()
# Out:
#      customer_id  gender  age  annual_income  spending_score  is_female
# 50            51  Female   49             42              52          1
# 127          128    Male   40             71              95          0
# 37            38  Female   30             34              73          1
# 149          150    Male   34             78              90          0
# 19            20  Female   35             23              98          1

# %%
# lets do some pair plots


explore.plot_variables_pairs(train)

# %%
explore.plot_categorical_and_continuous(train, 
                                        continuous_variables = ['age', 'annual_income', 'spending_score'], 
                                        categorical_variables = ['gender', 'is_female'])

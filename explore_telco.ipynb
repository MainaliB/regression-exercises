# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import acquire
import wrangle
import explore
import sklearn.preprocessing

# %%
df = acquire.get_telco_data()

# %%
df = wrangle.wrangle_telco(df)

# %%
train, test, validate = wrangle.split_data(df)

# %%
train.shape, test.shape, validate.shape
# Out:
# ((1217, 4), (253, 4), (215, 4))

# %%
cols_to_scale = ['monthly_charges', 'total_charges']
train, test, validate = wrangle.scale_data(train, test, validate, cols_to_scale = cols_to_scale, scaler = sklearn.preprocessing.MinMaxScaler())

# %%
train
# Out:
#      customer_id  monthly_charges  tenure  total_charges  \
# 5510  9861-PDSZP           108.05      72        7806.60
# 5431  8041-TMEID           108.50      63        6991.90
# 2383  9443-JUBUO            65.25      72        4478.85
# 2381  9415-ZNBSX            89.00      70        6293.20
# 6670  3976-HXHCE            19.30      72        1414.80
# ...          ...              ...     ...            ...
# 6566  2481-SBOYW            25.00      61        1498.35
# 2148  5915-ANOEI            79.15      70        5536.50
# 6433  0505-SPOOW            19.80      70        1397.65
# 2406  9795-NREXC            85.00      64        5484.40
# 2008  3704-IEAXF            53.65      72        3784.00
#
#       monthly_charges_scaled  total_charges_scaled
# 5510                0.893373              0.899926
# 5431                0.897857              0.805764
# 2383                0.466866              0.515308
# 2381                0.703538              0.725009
# 6670                0.008969              0.161169
# ...                      ...                   ...
# 6566                0.065770              0.170826
# 2148                0.605381              0.637550
# 6433                0.013951              0.159187
# 2406                0.663677              0.631529
# 2008                0.351271              0.434998
#
# [1217 rows x 6 columns]

# %% [markdown]
# - Write a function named plot_variable_pairs that accepts a dataframe as input and plots all of the pairwise relationships along with the regression line for each pair.

# %%
explore.plot_variables_pairs(train)

# %%
explore.months_to_years(train)
# Out:
#      customer_id  monthly_charges  tenure  total_charges  \
# 5510  9861-PDSZP           108.05      72        7806.60
# 5431  8041-TMEID           108.50      63        6991.90
# 2383  9443-JUBUO            65.25      72        4478.85
# 2381  9415-ZNBSX            89.00      70        6293.20
# 6670  3976-HXHCE            19.30      72        1414.80
# ...          ...              ...     ...            ...
# 6566  2481-SBOYW            25.00      61        1498.35
# 2148  5915-ANOEI            79.15      70        5536.50
# 6433  0505-SPOOW            19.80      70        1397.65
# 2406  9795-NREXC            85.00      64        5484.40
# 2008  3704-IEAXF            53.65      72        3784.00
#
#       monthly_charges_scaled  total_charges_scaled  tenure_years
# 5510                0.893373              0.899926           6.0
# 5431                0.897857              0.805764           5.0
# 2383                0.466866              0.515308           6.0
# 2381                0.703538              0.725009           6.0
# 6670                0.008969              0.161169           6.0
# ...                      ...                   ...           ...
# 6566                0.065770              0.170826           5.0
# 2148                0.605381              0.637550           6.0
# 6433                0.013951              0.159187           6.0
# 2406                0.663677              0.631529           5.0
# 2008                0.351271              0.434998           6.0
#
# [1217 rows x 7 columns]

# %%
explore.plot_categorical_and_continuous(train, cont_variables = ['tenure', 'monthly_charges', 'total_charges'], categorical_variables = ['tenure_years'])

# %% [markdown]
# - Explore your dataset with any other visualizations you think will be helpful.

# %%
train.groupby(train.tenure_years).monthly_charges.mean().plot()
# Out:
# <AxesSubplot:xlabel='tenure_years'>
